# %% [markdown]
# # Title

# %% [markdown]
# ## Metadata
#
# - Teaching: TIME_IN_MINUTES
# - Exercises: TIME_IN_MINUTES

# %% [markdown]
# ## Questions
#
# -

# %% [markdown]
# ## Objectives
#
# -

# %% [markdown]
# ## Markdown
#
# Text as markdown

# %% [markdown]
# #### Callout
#
# Callout text

# %%
# Code block

# %% [markdown]
# ## Keypoints
#
# -

# %% [markdown]
# ### Challenge

# %% [markdown]
# The solution to the preceding challenge
